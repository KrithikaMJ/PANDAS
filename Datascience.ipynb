# %% [markdown]
# <a href="https://colab.research.google.com/github/KrithikaMJ/PANDAS/blob/main/Datascience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PANDAS**
#  Import pandas as pd

# %% [markdown]
# # New Section

# %%
import pandas as pd
data=[20,30,40,90]
s=pd.Series(data)
print(s)
# Out:
# 0    20
# 1    30
# 2    40
# 3    90
# dtype: int64

# %%
import pandas as pd
data=[20,30,40,90]
s=pd.Series(data,index=["A","B","C","D"])
print(s)
# Out:
# A    20
# B    30
# C    40
# D    90
# dtype: int64

# %%
import pandas as pd
data={"Name":"Krithika","Age":19,"City":"Thrissur"}
s=pd.Series(data)
print(s)
# Out:
# Name    Krithika
# Age           19
# City    Thrissur
# dtype: object

# %% [markdown]
# **loc=label and iloc=position**

# %%
data=[30,40,20,50,10]
s=pd.Series(data)
print(s)
# Out:
# 0    30
# 1    40
# 2    20
# 3    50
# 4    10
# dtype: int64

# %%
data=[30,40,20,50,10]
s=pd.Series(data)
print(s.loc[1])
# Out:
# 40

# %%
data=[30,40,20,50,10]
s=pd.Series(data,index=["A","B","C","D","E"])
print(s.iloc[0])
print(s.loc["B"])
print(s[2:4])
# Out:
# 30
# 40
# C    20
# D    50
# dtype: int64

# %%
a=[1,2,3,4,5]
i=pd.Series(a,index=["a","b","c","d","e"])
print(i.iloc[1:3])
print(i.loc["a":"d"])
# Out:
# b    2
# c    3
# dtype: int64
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
import pandas as pd
sales = pd.Series( [1200,850,1500,950,2000],
                   index = ["Monday","Tuesday","Wednesday","Thursday","Friday"]
)
print(sales)
# Out:
# Monday       1200
# Tuesday       850
# Wednesday    1500
# Thursday      950
# Friday       2000
# dtype: int64

# %%
import pandas as pd
sales = pd.Series( [1200,850,1500,950,2000],
                   index = ["Monday","Tuesday","Wednesday","Thursday","Friday"]
)
print(sales)
print("Maximum sale =",sales.max())
print("Minimum sale =",sales.min())
print("Sum of sales =",sales.sum())
print("Below 1000\n",sales[sales<1000])
# Out:
# Monday       1200
# Tuesday       850
# Wednesday    1500
# Thursday      950
# Friday       2000
# dtype: int64
# Maximum sale = 2000
# Minimum sale = 850
# Sum of sales = 6500
# Below 1000
#  Tuesday     850
# Thursday    950
# dtype: int64

# %%
import pandas as pd
data=[20,20,30,30,50,60,60,80]
ar=pd.Series(data)
print(ar)
print(ar.unique())
print(ar.nunique())
print(ar.value_counts())                          # count for unique
# Out:
# 0    20
# 1    20
# 2    30
# 3    30
# 4    50
# 5    60
# 6    60
# 7    80
# dtype: int64
# [20 30 50 60 80]
# 5
# 20    2
# 30    2
# 60    2
# 50    1
# 80    1
# Name: count, dtype: int64

# %%
a=[None,20,10,None]
ar=pd.Series(a)
print(ar)
print(ar.isnull())
print(ar.notnull())
# Out:
# 0     NaN
# 1    20.0
# 2    10.0
# 3     NaN
# dtype: float64
# 0     True
# 1    False
# 2    False
# 3     True
# dtype: bool
# 0    False
# 1     True
# 2     True
# 3    False
# dtype: bool

# %%
import pandas as pd
marks = pd.Series([78,45,89,None,67,92,56,78,None,34],
                  index=["Anu","Rahul","Meera","Arun","Neha",
                         "vishnu","Diya","Akhil","Riya","Kiran"])

# %% [markdown]
# 1. find the no of students and total marks
# 2. find the averge,highest and lowest marks
# 3. find the name o the students with highest mark
# 4. check and count the missing values
# 5. replce the missing value with 0
# 6. find the unique marks and the no of unique marks
# 7. find the std who score above 70
# 8. sort the marks in descending order

# %%
import pandas as pd
import numpy as np
data={
   "Name   ":["Alice  ","Bob    ","Charlie","David  ","Emma   "],
   " Age":[20,21,19,22,20],
   "  Marks":[85,72,np.nan,90,65],
   " Attendance":[95,80,75,np.nan,88],
   "City   ":["Kochi  ","Delhi  ","Mumbai ","Kochi  ","Chennai"]
}
df=pd.DataFrame(data)
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#    Name      Age    Marks   Attendance  City
# 0  Alice      20     85.0         95.0  Kochi
# 1  Bob        21     72.0         80.0  Delhi
# 2  Charlie    19      NaN         75.0  Mumbai
# 3  David      22     90.0          NaN  Kochi
# 4  Emma       20     65.0         88.0  Chennai

# %% [markdown]
# **Create DataFrame**

# %%
print(df.head(3))                                    #for printing needed rows or columns
                                                     #df.head for first and * df.tail for last
# Out:
#    Name      Age    Marks   Attendance  City
# 0  Alice      20     85.0         95.0  Kochi
# 1  Bob        21     72.0         80.0  Delhi
# 2  Charlie    19      NaN         75.0  Mumbai

# %%
print(df.tail(2))
# Out:
#    Name      Age    Marks   Attendance  City
# 3  David      22     90.0          NaN  Kochi
# 4  Emma       20     65.0         88.0  Chennai

# %%
print(df.shape)
print(df.columns)
# Out:
# (5, 5)
# Index(['Name   ', ' Age', '  Marks', ' Attendance', 'City   '], dtype='object')

# %%
print(df.dtypes)                       #for dtatypes
# Out:
# Name            object
#  Age             int64
#   Marks        float64
#  Attendance    float64
# City            object
# dtype: object

# %%
print(df["  Marks"])                          # Marks change aaki vere eath venelum aakan pattum(name,age,city.......)
# Out:
# 0    85.0
# 1    72.0
# 2     NaN
# 3    90.0
# 4    65.0
# Name:   Marks, dtype: float64

# %%
print(df.iloc[0:3])
# Out:
#    Name      Age    Marks   Attendance  City
# 0  Alice      20     85.0         95.0  Kochi
# 1  Bob        21     72.0         80.0  Delhi
# 2  Charlie    19      NaN         75.0  Mumbai

# %%
print(df.iloc[1:5])                                        # end number include aavilla
# Out:
#    Name      Age    Marks   Attendance  City
# 1  Bob        21     72.0         80.0  Delhi
# 2  Charlie    19      NaN         75.0  Mumbai
# 3  David      22     90.0          NaN  Kochi
# 4  Emma       20     65.0         88.0  Chennai

# %%
print(df.loc[0:3,["Name   ","  Marks"]])                  # end number include aavum
# Out:
#    Name       Marks
# 0  Alice       85.0
# 1  Bob         72.0
# 2  Charlie      NaN
# 3  David       90.0

# %%
print(df[df["  Marks"] > 75])
# Out:
#    Name      Age    Marks   Attendance  City
# 0  Alice      20     85.0         95.0  Kochi
# 3  David      22     90.0          NaN  Kochi

# %%
print(df[df["  Marks"] < 75])
# Out:
#    Name      Age    Marks   Attendance  City
# 1  Bob        21     72.0         80.0  Delhi
# 4  Emma       20     65.0         88.0  Chennai

# %%
print(df[df["  Marks"] == 72])
# Out:
#    Name      Age    Marks   Attendance  City
# 1  Bob        21     72.0         80.0  Delhi

# %%
print(df[df["  Marks"] == 75])
# Out:
# Empty DataFrame
# Columns: [Name   ,  Age,   Marks,  Attendance, City   ]
# Index: []

# %%
print(df[df["City   "] == "Kochi  "])
# Out:
#    Name      Age    Marks   Attendance  City
# 0  Alice      20     85.0         95.0  Kochi
# 3  David      22     90.0          NaN  Kochi

# %%
print(
    df[
    (df["  Marks"] < 75)
           &
    (df[" Attendance"] > 50)
    ]
)
# Out:
#    Name      Age    Marks   Attendance  City
# 1  Bob        21     72.0         80.0  Delhi
# 4  Emma       20     65.0         88.0  Chennai

# %%
print(df['  Marks'].mean(),": Mean")
print(df['  Marks'].max(),": Max")
print(df['  Marks'].sum(),": Sum")
print(df['  Marks'].min(),": Min")
print(df.sort_values('  Marks'))
print(df.sort_values('  Marks',ascending=False))
# Out:
# 78.0 : Mean
# 90.0 : Max
# 312.0 : Sum
# 65.0 : Min
#    Name      Age    Marks   Attendance  City
# 4  Emma       20     65.0         88.0  Chennai
# 1  Bob        21     72.0         80.0  Delhi
# 0  Alice      20     85.0         95.0  Kochi
# 3  David      22     90.0          NaN  Kochi
# 2  Charlie    19      NaN         75.0  Mumbai
#    Name      Age    Marks   Attendance  City
# 3  David      22     90.0          NaN  Kochi
# 0  Alice      20     85.0         95.0  Kochi
# 1  Bob        21     72.0         80.0  Delhi
# 4  Emma       20     65.0         88.0  Chennai
# 2  Charlie    19      NaN         75.0  Mumbai

# %%
df_renamed = df.rename(
    columns={
        "Marks":"Score",
        "Attendance":"Attendance_percentage"
    }
)
print(df_renamed)
print(df.isna())
print(df.isna().sum())
# Out:
#    Name      Age    Marks   Attendance  City
# 0  Alice      20     85.0         95.0  Kochi
# 1  Bob        21     72.0         80.0  Delhi
# 2  Charlie    19      NaN         75.0  Mumbai
# 3  David      22     90.0          NaN  Kochi
# 4  Emma       20     65.0         88.0  Chennai
#    Name       Age    Marks   Attendance  City
# 0    False  False    False        False    False
# 1    False  False    False        False    False
# 2    False  False     True        False    False
# 3    False  False    False         True    False
# 4    False  False    False        False    False
# Name           0
#  Age           0
#   Marks        1
#  Attendance    1
# City           0
# dtype: int64

# %%
print(df.dropna())                                   # dropna remove NaN frm the given
# Out:
#    Name      Age    Marks   Attendance  City
# 0  Alice      20     85.0         95.0  Kochi
# 1  Bob        21     72.0         80.0  Delhi
# 4  Emma       20     65.0         88.0  Chennai

# %%
df_forward = df.copy()                            # df_forward.ffill uesd to fill NaN space with above number
df_forward = df_forward.ffill()
print(df_forward)
# Out:
#    Name      Age    Marks   Attendance  City
# 0  Alice      20     85.0         95.0  Kochi
# 1  Bob        21     72.0         80.0  Delhi
# 2  Charlie    19     72.0         75.0  Mumbai
# 3  David      22     90.0         75.0  Kochi
# 4  Emma       20     65.0         88.0  Chennai

# %%
df_backward = df.copy()                            # df_backward.bfill uesd to fill NaN space with below number
df_backward = df_backward.bfill()
print(df_backward)
# Out:
#    Name      Age    Marks   Attendance  City
# 0  Alice      20     85.0         95.0  Kochi
# 1  Bob        21     72.0         80.0  Delhi
# 2  Charlie    19     90.0         75.0  Mumbai
# 3  David      22     90.0         88.0  Kochi
# 4  Emma       20     65.0         88.0  Chennai

# %%
df=pd.read_csv("/content/nigeria_messy_sales_dataset (2).csv")
df
# Out:
#           Customer Name    State     Product  Units Sold  Unit Price  \
# 0                   NaN   rivers    KEYBOARD         NaN         NaN
# 1          Allison Hill    Lagos  Headphones         NaN   267992.94
# 2           Noah Rhodes  Anambra    Keyboard         NaN    42364.41
# 3       Angie Henderson    Delta    Keyboard         NaN   279444.94
# 4         Daniel Wagner    Delta      Tablet         NaN    95899.74
# ..                  ...      ...         ...         ...         ...
# 545    Zachary Mitchell    Ekiti     Monitor         6.0    23989.09
# 546                 NaN  Katsina      Tablet         NaN   223764.24
# 547  Katherine Martinez   Bauchi       Phone         NaN   104084.92
# 548          Jodi Roach    Niger     Charger         NaN    29756.89
# 549     Brandon Fleming      imo      Camera         NaN    70027.13
#
#      Total Sale   Sale Date Sales Channel  \
# 0           NaN  2025-04-27        Online
# 1           NaN  2024-03-15     Wholesale
# ...

# %% [markdown]
# 1. Load the Nigeria sales dataset into a DataFrame named sales_df. Display the dataset and identify the number of records and columns available.
# 2. The manager wants to review basic information about the sales data. Display the first 7 records and the last 5 records.
# 3. The sales team wants to focus on the Product, Units Sold, Unit Price, and Total Sale information. Display only these details.
# 4. Find all sales transactions where the Units Sold is greater than 50. Display the complete records.
# 5. The manager wants to identify transactions where the Unit Price is greater than 100,000. Display the relevant sales records.
# 6. Find all transactions made through the Online sales channel.
# 7. The manager wants to know which different states are present in the dataset. Also determine how many different states are available.
# 8. Find out how many sales transactions belong to each Sales Channel.
# 9. The company wants to understand the quality of the dataset. Find the number of missing values present in each column.
# 10. Prepare a new dataset containing only records with complete information. Then find how many records remain after removing incomplete records.

# %% [markdown]
# 1

# %%
df.shape
# Out:
# (550, 9)

# %% [markdown]
# 2

# %%
df.head(7)
# Out:
#      Customer Name    State     Product  Units Sold  Unit Price  Total Sale  \
# 0              NaN   rivers    KEYBOARD         NaN         NaN         NaN
# 1     Allison Hill    Lagos  Headphones         NaN   267992.94         NaN
# 2      Noah Rhodes  Anambra    Keyboard         NaN    42364.41         NaN
# 3  Angie Henderson    Delta    Keyboard         NaN   279444.94         NaN
# 4    Daniel Wagner    Delta      Tablet         NaN    95899.74         NaN
# 5  Cristian Santos      Oyo      Camera         NaN   118189.90         NaN
# 6  Connie Lawrence   Rivers      Tablet        36.0   185141.90   6665108.4
#
#     Sale Date Sales Channel                              Order ID
# 0  2025-04-27        Online                                   NaN
# 1  2024-03-15     Wholesale  4c636e95-025f-4543-8997-623ae0723d96
# 2  2024-12-10           NaN  edaf3766-1b78-4ede-9a4f-fc0c9165f2ed
# 3  2024-04-05           NaN  74503887-48d9-4846-95c5-51fcfba57cc8
# ...

# %%
df.tail(5)
# Out:
#           Customer Name    State  Product  Units Sold  Unit Price  Total Sale  \
# 545    Zachary Mitchell    Ekiti  Monitor         6.0    23989.09   143934.54
# 546                 NaN  Katsina   Tablet         NaN   223764.24         NaN
# 547  Katherine Martinez   Bauchi    Phone         NaN   104084.92         NaN
# 548          Jodi Roach    Niger  Charger         NaN    29756.89         NaN
# 549     Brandon Fleming      imo   Camera         NaN    70027.13         NaN
#
#       Sale Date Sales Channel                              Order ID
# 545  2025-07-07     Wholesale  b9744cde-d259-4960-aee3-560792ea1324
# 546  2025-02-11     Wholesale                                   NaN
# 547  2025-05-18        Retail  61fa8e7a-078c-46ce-bf02-23bc651ea252
# 548  2025-06-29        Direct  5a9c0679-2c3d-47e2-ad39-da75aee70ab2
# 549  2024-02-20           NaN  46653497-2fe9-42aa-a886-a01136f7a26c

# %% [markdown]
# 3

# %%
(df["Product"],["Units Sold"],["Unit Price"],["Total Sale"])
# Out:
# (0        KEYBOARD
#  1      Headphones
#  2        Keyboard
#  3        Keyboard
#  4          Tablet
#            ...
#  545       Monitor
#  546        Tablet
#  547         Phone
#  548       Charger
#  549        Camera
#  Name: Product, Length: 550, dtype: object,
#  ['Units Sold'],
#  ['Unit Price'],
#  ['Total Sale'])

# %% [markdown]
# 4

# %%
(df[df["Units Sold"]>50])
# Out:
#             Customer Name        State     Product  Units Sold  Unit Price  \
# 19           Derek Zuniga          Imo  Headphones        77.0    92649.51
# 31          Zachary Hicks      Anambra      Camera        68.0    15880.87
# 32      Anthony Rodriguez          Oyo     MONITOR        96.0   144394.41
# 37         Debra Davidson        Benue       Phone        65.0   246587.56
# 38         Jeffrey Chavez       Rivers     Charger        79.0    73037.87
# ..                    ...          ...         ...         ...         ...
# 515       Julie Dominguez  Cross River     Monitor        59.0   270431.25
# 522         Howard Norman        benue      Camera        69.0    84471.72
# 528      Samantha Gardner       Rivers  HEADPHONES        52.0    62543.86
# 541         Phillip Berry       Bauchi  Headphones        97.0   115461.94
# 544  Mr. Justin Green III       Sokoto    KEYBOARD        65.0   206948.51
#
#       Total Sale   Sale Date Sales Channel  \
# ...

# %% [markdown]
# 5

# %%
(df[df["Unit Price"]>100000])
# Out:
#             Customer Name    State     Product  Units Sold  Unit Price  \
# 1            Allison Hill    Lagos  Headphones         NaN   267992.94
# 3         Angie Henderson    Delta    Keyboard         NaN   279444.94
# 5         Cristian Santos      Oyo      Camera         NaN   118189.90
# 6         Connie Lawrence   Rivers      Tablet        36.0   185141.90
# 7         Abigail Shaffer      Imo    Keyboard         NaN   252859.28
# ..                    ...      ...         ...         ...         ...
# 542        Jennifer Banks      Imo     Monitor         NaN   222053.68
# 543      Brian Fitzgerald  Katsina      Laptop         NaN   237254.18
# 544  Mr. Justin Green III   Sokoto    KEYBOARD        65.0   206948.51
# 546                   NaN  Katsina      Tablet         NaN   223764.24
# 547    Katherine Martinez   Bauchi       Phone         NaN   104084.92
#
#       Total Sale   Sale Date Sales Channel  \
# 1            NaN  2024-03-15     Wholesale
# ...

# %% [markdown]
# 6

# %%
df[df["Sales Channel"]=="Online"]
# Out:
#             Customer Name   State     Product  Units Sold  Unit Price  \
# 0                     NaN  rivers    KEYBOARD         NaN         NaN
# 7         Abigail Shaffer     Imo    Keyboard         NaN   252859.28
# 19           Derek Zuniga     Imo  Headphones        77.0    92649.51
# 23            Patty Perez   Delta      Camera         NaN   188963.51
# 24            Ethan Adams   Ekiti      LAPTOP         4.0   179274.43
# ..                    ...     ...         ...         ...         ...
# 525       Jasmine Beltran   Delta      Tablet         NaN    54216.67
# 534         William Gould   Abuja      Laptop         NaN    90133.43
# 538        Austin Osborne   Ekiti    Keyboard         NaN   203271.97
# 542        Jennifer Banks     Imo     Monitor         NaN   222053.68
# 544  Mr. Justin Green III  Sokoto    KEYBOARD        65.0   206948.51
#
#       Total Sale   Sale Date Sales Channel  \
# 0            NaN  2025-04-27        Online
# ...

# %% [markdown]
# 7

# %%
print(df["State"].unique())
(df["State"].nunique())
# Out:
# ['rivers' 'Lagos' 'Anambra' 'Delta' 'Oyo' 'Rivers' 'Imo' 'Kano' 'plateau'
#  'Niger' 'Abuja' 'Enugu' 'Bauchi' 'Katsina' 'lagos' 'Ekiti' 'Plateau'
#  'Kaduna' 'Sokoto' 'kano' 'Benue' 'Osun' 'imo' 'Borno' 'enugu' 'anambra'
#  'katsina' 'delta' 'Cross River' 'oyo' 'osun' 'kaduna' 'niger' 'borno'
#  'abuja' 'bauchi' 'cross river' 'ekiti' 'sokoto' 'benue']
# 40

# %% [markdown]
# 8

# %%
df["Sales Channel"].value_counts()
# Out:
# Sales Channel
# Direct       124
# Wholesale    111
# Retail       108
# Online       101
# Name: count, dtype: int64

# %% [markdown]
# 9

# %%
df.isna()
# Out:
#      Customer Name  State  Product  Units Sold  Unit Price  Total Sale  \
# 0             True  False    False        True        True        True
# 1            False  False    False        True       False        True
# 2            False  False    False        True       False        True
# 3            False  False    False        True       False        True
# 4            False  False    False        True       False        True
# ..             ...    ...      ...         ...         ...         ...
# 545          False  False    False       False       False       False
# 546           True  False    False        True       False        True
# 547          False  False    False        True       False        True
# 548          False  False    False        True       False        True
# 549          False  False    False        True       False        True
#
#      Sale Date  Sales Channel  Order ID
# 0        False          False      True
# ...

# %% [markdown]
# 10

# %%
df.dropna()
# Out:
#             Customer Name   State     Product  Units Sold  Unit Price  \
# 6         Connie Lawrence  Rivers      Tablet        36.0   185141.90
# 11         Monica Herrera   Abuja      Laptop         3.0   153159.37
# 12           Jamie Arnold   Lagos      Tablet        43.0   147209.07
# 18             Holly Wood   lagos  Headphones        43.0   125253.81
# 19           Derek Zuniga     Imo  Headphones        77.0    92649.51
# ..                    ...     ...         ...         ...         ...
# 517         Judith Carter    Kano      Laptop        46.0   170251.85
# 527         Monica Miller   Lagos      Laptop        47.0     5189.60
# 537   Lawrence Harrington  Rivers     Monitor        16.0   254908.01
# 544  Mr. Justin Green III  Sokoto    KEYBOARD        65.0   206948.51
# 545      Zachary Mitchell   Ekiti     Monitor         6.0    23989.09
#
#       Total Sale   Sale Date Sales Channel  \
# 6     6665108.40  2024-09-10     Wholesale
# ...
